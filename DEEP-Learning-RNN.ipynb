# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense

import warnings
warnings.filterwarnings("ignore")

# %%
train_data=pd.read_csv("tweets_train.csv")
train_data.head()
# Out:
#         user_name               user_location  \
# 0          Romy 👑            Bolton - England
# 1  TLynn Peterson  Black Canyon City, Arizona
# 2  Rutger Kosters                 Netherlands
# 3      IDFWU🗯🇿🇼🇿🇦   East London, South Africa
# 4         Treebel                         NaN
#
#                                     user_description         user_created  \
# 0     Tables turn, bridges burn, you live and learn.  2009-06-15 09:00:39
# 1  Acquired disability ♿ after an accident. Livin...  2013-05-29 00:17:46
# 2  Cloud Solution Architect @NetApp | VCDX #209 |...  2014-10-07 09:34:10
# 3  YOU HAVE OPTIONS, YOU CAN’T JUST TAKE WHAT LIF...  2012-08-22 11:09:06
# 4                                                NaN  2010-09-25 07:25:31
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             525           896             3854          False
# 1            5045          5374            48152          False
# 2             574           251             1070          False
# 3             706           618             1320          False
# 4               9            13               55          False
#
#                   date              hashtags               source  is_retweet  \
# 0  2020-09-19 15:19:32  ['TheSocialDilemma']  Twitter for Android       False
# 1  2020-09-13 00:31:46  ['TheSocialDilemma']  Twitter for Android       False
# 2  2020-09-09 21:10:33  ['TheSocialDilemma']  Twitter for Android       False
# 3  2020-09-11 04:33:08                   NaN  Twitter for Android       False
# 4  2020-09-17 16:27:38  ['thesocialdilemma']   Twitter for iPhone       False
#
#                                           clean_text Sentiment
# 0  TheSocialDilemma is an eye opener isn t it ple...   Neutral
# 1  TheSocialDilemma If we don t agree on what is ...  Positive
# 2  Watching TheSocialDilemma scary to see social ...  Negative
# 3  You check your social media before you pee in ...  Positive
# 4  watch thesocialdilemma and see what s actually...  Negative

# %%
test_data=pd.read_csv("tweets_test.csv")
test_data.head()
# Out:
#                    user_name          user_location  \
# 0                  Doug Webb        Probably Europe
# 1                Dan Reynish  Medicine Hat, Alberta
# 2                          🌤                    NaN
# 3  “IT IS WHAT IT IS.”🇰🇪🇳🇿🇺🇸                     WA
# 4                Mahima Sood                    NaN
#
#                                     user_description         user_created  \
# 0  I develop methods for effective cooperation, w...  2015-12-12 15:22:58
# 1  News Anchor at Noon and 5 pm on CHAT TV. Canad...  2011-09-10 12:17:10
# 2                                                NaN  2011-06-01 02:23:57
# 3  Heliophile🌞☀️• #Rugby • Wildlifer • #HIV • #So...  2009-04-17 13:35:02
# 4  Amy Dunne X Holly Golightly || Data Scientist ...  2018-01-26 21:57:22
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             157           228              496          False
# 1            1722          2500            13912          False
# 2             880           585              205          False
# 3            1143          2692            11999          False
# 4              18            65              263          False
#
#                   date                              hashtags  \
# 0  2020-09-15 22:53:36  ['theSocialDilemma', 'joinMastodon']
# 1  2020-09-12 04:43:03                        ['WeTheNorth']
# 2  2020-09-19 07:06:53                  ['TheSocialDilemma']
# 3  2020-09-12 18:28:18       ['TheSocialDilemma', 'Netflix']
# 4  2020-09-12 18:48:53                  ['TheSocialDilemma']
#
#                source  is_retweet  \
# 0     Twitter Web App       False
# 1     Twitter Web App       False
# 2  Twitter for iPhone       False
# 3  Twitter for iPhone       False
# 4  Twitter for iPhone       False
#
#                                           clean_text
# 0           Watch theSocialDilemma then joinMastodon
# 1  With the 2019 2020 NBA season officially over ...
# 2  if you want to really know about people go tal...
# 3       Have you watched TheSocialDilemma on Netflix
# 4               Highly recommend TheSocialDilemma on

# %%
train_data.shape
# Out:
# (17000, 14)

# %%
test_data.shape
# Out:
# (3068, 13)

# %%
train_data.isnull().sum()
# Out:
# user_name              1
# user_location       3607
# user_description    1162
# user_created           0
# user_followers         0
# user_friends           0
# user_favourites        0
# user_verified          0
# date                   0
# hashtags            3649
# source                 0
# is_retweet             0
# clean_text             8
# Sentiment              0
# dtype: int64

# %%
test_data.isnull().sum()
# Out:
# user_name             0
# user_location       601
# user_description    221
# user_created          0
# user_followers        0
# user_friends          0
# user_favourites       0
# user_verified         0
# date                  0
# hashtags            648
# source                0
# is_retweet            0
# clean_text            1
# dtype: int64

# %%
train_data.fillna("", inplace=True)
test_data.fillna("", inplace=True)

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(train_data['clean_text'])
sequences = tokenizer.texts_to_sequences(train_data['clean_text'])
max_sequence_length = max([len(x) for x in sequences])
word_index = tokenizer.word_index

# %%
data = pad_sequences(sequences, maxlen=max_sequence_length)

# %%
target = pd.get_dummies(train_data['Sentiment'])

# %%
X_train, X_val, y_train, y_val = train_test_split(data, target, test_size=0.2, random_state=42)

# %%
model = Sequential()

# %%
model.add(Embedding(len(word_index) + 1, 100, input_length=max_sequence_length))

# %%
model.add(SimpleRNN(128))

# %%
model.add(Dense(3, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=20, batch_size=64)
# Out:
# Epoch 1/20
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001C4A76F9EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001C4A76F9EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 211/213 [============================>.] - ETA: 0s - loss: 0.7799 - accuracy: 0.6628WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001C4A9BD8318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001C4A9BD8318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 213/213 [==============================] - 7s 29ms/step - loss: 0.7786 - accuracy: 0.6635 - val_loss: 0.5754 - val_accuracy: 0.7876
# Epoch 2/20
# 213/213 [==============================] - 6s 27ms/step - loss: 0.3245 - accuracy: 0.8828 - val_loss: 0.4536 - val_accuracy: 0.8368
# Epoch 3/20
# 213/213 [==============================] - 6s 28ms/step - loss: 0.1064 - accuracy: 0.9669 - val_loss: 0.4594 - val_accuracy: 0.8468
# Epoch 4/20
# 213/213 [==============================] - 6s 28ms/step - loss: 0.0412 - accuracy: 0.9899 - val_loss: 0.5140 - val_accuracy: 0.8482
# Epoch 5/20
# 213/213 [==============================] - 6s 28ms/step - loss: 0.0234 - accuracy: 0.9938 - val_loss: 0.5459 - val_accuracy: 0.8500
# Epoch 6/20
# 213/213 [==============================] - 6s 27ms/step - loss: 0.0113 - accuracy: 0.9978 - val_loss: 0.6513 - val_accuracy: 0.8444
# Epoch 7/20
# 213/213 [==============================] - 6s 30ms/step - loss: 0.0069 - accuracy: 0.9988 - val_loss: 0.6550 - val_accuracy: 0.8641
# Epoch 8/20
# 213/213 [==============================] - 7s 31ms/step - loss: 0.0517 - accuracy: 0.9820 - val_loss: 0.7723 - val_accuracy: 0.8115
# Epoch 9/20
# 213/213 [==============================] - 6s 28ms/step - loss: 0.0525 - accuracy: 0.9824 - val_loss: 0.6166 - val_accuracy: 0.8324
# Epoch 10/20
# 213/213 [==============================] - 6s 28ms/step - loss: 0.0208 - accuracy: 0.9936 - val_loss: 0.7008 - val_accuracy: 0.8176
# Epoch 11/20
# 213/213 [==============================] - 6s 28ms/step - loss: 0.0159 - accuracy: 0.9959 - val_loss: 0.6655 - val_accuracy: 0.8482
# Epoch 12/20
# 213/213 [==============================] - 6s 28ms/step - loss: 0.0525 - accuracy: 0.9854 - val_loss: 0.6665 - val_accuracy: 0.8341
# Epoch 13/20
# 213/213 [==============================] - 6s 28ms/step - loss: 0.0200 - accuracy: 0.9938 - val_loss: 0.8219 - val_accuracy: 0.8065
# Epoch 14/20
# 213/213 [==============================] - 6s 28ms/step - loss: 0.0066 - accuracy: 0.9982 - val_loss: 0.7260 - val_accuracy: 0.8459
# Epoch 15/20
# 213/213 [==============================] - 6s 28ms/step - loss: 0.0022 - accuracy: 0.9996 - val_loss: 0.7227 - val_accuracy: 0.8538
# Epoch 16/20
# 213/213 [==============================] - 6s 28ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.7291 - val_accuracy: 0.8579
# Epoch 17/20
# 213/213 [==============================] - 6s 28ms/step - loss: 9.7910e-04 - accuracy: 0.9999 - val_loss: 0.7909 - val_accuracy: 0.8391
# Epoch 18/20
# 213/213 [==============================] - 6s 28ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.7728 - val_accuracy: 0.8526
# Epoch 19/20
# 213/213 [==============================] - 6s 28ms/step - loss: 4.7771e-04 - accuracy: 0.9999 - val_loss: 0.7606 - val_accuracy: 0.8606
# Epoch 20/20
# 213/213 [==============================] - 6s 28ms/step - loss: 7.9188e-04 - accuracy: 0.9998 - val_loss: 0.7748 - val_accuracy: 0.8585

# %%
loss, accuracy = model.evaluate(X_val, y_val)
print(f'Validation Accuracy: {accuracy}')
# Out:
# 107/107 [==============================] - 0s 3ms/step - loss: 0.7748 - accuracy: 0.8585
# Validation Accuracy: 0.8585293889045715

# %%
test_sequences = tokenizer.texts_to_sequences(test_data['clean_text'])
test_data_padded = pad_sequences(test_sequences, maxlen=max_sequence_length)

# %%
predictions = model.predict(test_data_padded)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001C4A9B49F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001C4A9B49F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 96/96 [==============================] - 0s 3ms/step

# %%
sentiment_labels = ['Negative', 'Neutral', 'Positive']
predicted_labels = [sentiment_labels[np.argmax(pred)] for pred in predictions]

# %%
test_data['Predicted_Sentiment'] = predicted_labels

# %%
test_data.to_csv("test_data_with_predictions.csv", index=False)

# %%
df=pd.read_csv("test_data_with_predictions.csv")
df
# Out:
#                       user_name          user_location  \
# 0                     Doug Webb        Probably Europe
# 1                   Dan Reynish  Medicine Hat, Alberta
# 2                             🌤                    NaN
# 3     “IT IS WHAT IT IS.”🇰🇪🇳🇿🇺🇸                     WA
# 4                   Mahima Sood                    NaN
# ...                         ...                    ...
# 3063                     𝘔𝘶𝘳𝘪;🦋       𝘶𝘯𝘥𝘦𝘳 𝘵𝘩𝘦 𝘱𝘢𝘭𝘮𝘴🌴
# 3064              Didi Crawford    Birmingham, England
# 3065               Ritwik Arora                    NaN
# 3066               Nishant Mody                 Mumbai
# 3067       Quarantine James 🏁🇻🇨            Brooklyn!!!
#
#                                        user_description         user_created  \
# 0     I develop methods for effective cooperation, w...  2015-12-12 15:22:58
# 1     News Anchor at Noon and 5 pm on CHAT TV. Canad...  2011-09-10 12:17:10
# 2                                                   NaN  2011-06-01 02:23:57
# 3     Heliophile🌞☀️• #Rugby • Wildlifer • #HIV • #So...  2009-04-17 13:35:02
# 4     Amy Dunne X Holly Golightly || Data Scientist ...  2018-01-26 21:57:22
# ...                                                 ...                  ...
# 3063      𝘸𝘪𝘧𝘦 // 𝘤𝘢𝘵 𝘮𝘰𝘮 // 𝘱𝘴𝘺𝘤𝘩𝘰𝘭𝘰𝘨𝘪𝘴𝘵; 🧠 𝘣𝘦𝘢𝘤𝘩𝘣𝘶𝘮;🌴  2009-07-29 03:18:16
# 3064  Traveller | Blogger | Currently growing a huma...  2011-12-06 09:24:20
# 3065  Spent the last 30 minutes writing this bio, ch...  2020-10-13 01:12:06
# 3066  I love music, dogs, nature, politics & marketi...  2012-12-30 04:58:15
# 3067  Co-founder of Mokete Events & photo booth rent...  2011-05-19 20:09:21
#
#       user_followers  user_friends  user_favourites  user_verified  \
# 0                157           228              496          False
# 1               1722          2500            13912          False
# 2                880           585              205          False
# 3               1143          2692            11999          False
# 4                 18            65              263          False
# ...              ...           ...              ...            ...
# 3063             942           357             9917          False
# 3064             468          1095             3440          False
# 3065              10           137              106          False
# 3066             174           541             5482          False
# 3067             332           328            14642          False
#
#                      date                              hashtags  \
# 0     2020-09-15 22:53:36  ['theSocialDilemma', 'joinMastodon']
# 1     2020-09-12 04:43:03                        ['WeTheNorth']
# 2     2020-09-19 07:06:53                  ['TheSocialDilemma']
# 3     2020-09-12 18:28:18       ['TheSocialDilemma', 'Netflix']
# 4     2020-09-12 18:48:53                  ['TheSocialDilemma']
# ...                   ...                                   ...
# 3063  2020-09-14 12:27:35                  ['TheSocialDilemma']
# 3064  2020-09-22 19:25:48                  ['TheSocialDilemma']
# 3065  2020-10-13 02:41:26                  ['TheSocialDilemma']
# 3066  2020-09-10 17:19:44                  ['TheSocialDilemma']
# 3067  2020-09-12 13:15:41                  ['TheSocialDilemma']
#
#                    source  is_retweet  \
# 0         Twitter Web App       False
# 1         Twitter Web App       False
# 2      Twitter for iPhone       False
# 3      Twitter for iPhone       False
# 4      Twitter for iPhone       False
# ...                   ...         ...
# 3063   Twitter for iPhone       False
# 3064   Twitter for iPhone       False
# 3065  Twitter for Android       False
# 3066   Twitter for iPhone       False
# 3067  Twitter for Android       False
#
#                                              clean_text Predicted_Sentiment
# 0              Watch theSocialDilemma then joinMastodon             Neutral
# 1     With the 2019 2020 NBA season officially over ...             Neutral
# 2     if you want to really know about people go tal...            Positive
# 3          Have you watched TheSocialDilemma on Netflix             Neutral
# 4                  Highly recommend TheSocialDilemma on            Positive
# ...                                                 ...                 ...
# 3063            Everybody should watch TheSocialDilemma             Neutral
# 3064            Enjoyed TheSocialDilemma Then read this             Neutral
# 3065  Couldn t stop thinking about docu TheSocialDil...            Negative
# 3066    This was the best one by on TheSocialDilemma on            Positive
# 3067                    TheSocialDilemma on Netflix wow            Positive
#
# [3068 rows x 14 columns]
